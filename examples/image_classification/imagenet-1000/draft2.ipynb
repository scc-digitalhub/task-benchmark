# %%
import pandas as pd

# %%
df = pd.read_csv("reports/model_comparison.csv")#.sort_values("accuracy", ascending=False).head(10)

# %%
df.drop(columns=["report_path"], inplace=True)

# %%
df
# Out:
#                           model_name                  task  implementation  \
# 0               microsoft/cvt-13-384  image-classification  task-inference
# 1  facebook/convnext-base-384-22k-1k  image-classification  task-inference
#
#    profile  top1_accuracy  top5_accuracy  dataset_images_evaluated  \
# 0  default          0.384          0.608                      1000
# 1  default          0.589          0.830                      1000
#
#    dataset_images_skipped  cpu_time_seconds  cpu_usage_percent  ...  \
# 0                       0        587.503866         192.394977  ...
# 1                       0       2598.677578         299.409314  ...
#
#    avg_batch_wall_time_seconds  avg_batch_memory_mb  \
# 0                    37.694340           806.201172
# 1                   108.257737           932.431641
#
#    min_batch_cpu_time_seconds  max_batch_cpu_time_seconds  \
# 0                   60.347384                   77.806044
# ...
